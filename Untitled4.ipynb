# %% [markdown]
# <a href="https://colab.research.google.com/github/nhantruongcse/Artificial-Intelligence-Of-Beginner/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/lescientifik/open_brats2020.git
# Out:
# Cloning into 'open_brats2020'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 85 (delta 6), reused 4 (delta 4), pack-reused 73
# Receiving objects: 100% (85/85), 10.54 MiB | 15.80 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %%
import tensorflow

# %%
# %cd /content/open_brats2020
# Out:
# /content/open_brats2020

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/lessw2020/Ranger-Deep-Learning-Optimizer.git to /tmp/pip-req-build-iq064foc
#   Running command git clone --filter=blob:none --quiet https://github.com/lessw2020/Ranger-Deep-Learning-Optimizer.git /tmp/pip-req-build-iq064foc
#   Resolved https://github.com/lessw2020/Ranger-Deep-Learning-Optimizer.git to commit c82a30460684c7301086d84185a1927b1c256afa
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 MB 32.7 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...

# %% [markdown]
# # data

# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b1d3342b-5ad3-48b4-80d3-d5c2b13d0f8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b1d3342b-5ad3-48b4-80d3-d5c2b13d0f8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                   title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# rahulvyasm/netflix-movies-and-tv-shows                Netflix Movies and TV Shows                           1MB  2024-04-10 09:48:38           4263         87  1.0
# prishasawhney/mushroom-dataset                        Mushroom Dataset (Binary Classification)            602KB  2024-04-18 19:56:44            688         50  1.0
# akankshaaa013/top-grossing-movies-dataset             Top Grossing Movies Dataset                          33KB  2024-04-08 08:29:47           1733         36  1.0
# ...

# %%
# !kaggle datasets download -d awsaf49/brats20-dataset-training-validation
# Out:
# ...
# 100% 4.16G/4.16G [00:36<00:00, 159MB/s]
# 100% 4.16G/4.16G [00:36<00:00, 123MB/s]

# %%
# !unzip -q brats20-dataset-training-validation.zip

# %% [markdown]
# # train

# %%
# !python -m src.train --devices 0 --width 48 --b 3 --arch EquiUnet
# Out:
# 2024-04-23 00:07:46.419148: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-23 00:07:46.419197: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-23 00:07:46.421488: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-23 00:07:47.474489: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Working with 1 GPUs
# {'arch': 'EquiUnet',
#  'batch_size': 3,
#  'com': None,
#  'debug': False,
#  'deep_sup': False,
#  'devices': '0',
#  'dropout': 0.0,
#  'epochs': 200,
# ...

# %% [markdown]
# # github

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !git config --global user.email truongvannhan@hotmail.com

# %%
# !git config --global user.name "nhantruongcse"

# %%
# !git add -A

# %%
# !git commit -m first_
# Out:
# [master (root-commit) 112a334] first_
#  2371 files changed, 51636 insertions(+)
#  create mode 100644 .config/.last_opt_in_prompt.yaml
#  create mode 100644 .config/.last_survey_prompt.yaml
#  create mode 100644 .config/.last_update_check.json
#  create mode 100644 .config/active_config
#  create mode 100644 .config/config_sentinel
#  create mode 100644 .config/configurations/config_default
#  create mode 100644 .config/default_configs.db
#  create mode 100644 .config/gce
#  create mode 100644 .config/logs/2024.04.19/13.29.23.074279.log
#  create mode 100644 .config/logs/2024.04.19/13.29.49.527067.log
#  create mode 100644 .config/logs/2024.04.19/13.29.59.974423.log
#  create mode 100644 .config/logs/2024.04.19/13.30.08.220712.log
#  create mode 100644 .config/logs/2024.04.19/13.30.19.119041.log
#  create mode 100644 .config/logs/2024.04.19/13.30.19.878106.log
# ...

# %%
# !git remote add origin https://nhantruongcse:vannhan.no1@github.com/nhantruongcse/mybraints.git
# Out:
# error: remote origin already exists.

# %%
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'https://github.com/nhantruongcse/mybraints.git'

# %%
# !git remote rm origin

# %%
# !pwd
# Out:
# /content
